# %%
pip install a2t
# Out:
# Requirement already satisfied: a2t in d:\application download for education\lib\site-packages (0.4.0)
# Requirement already satisfied: transformers in d:\application download for education\lib\site-packages (from a2t) (4.55.4)
# Requirement already satisfied: tqdm in d:\application download for education\lib\site-packages (from a2t) (4.67.1)
# Requirement already satisfied: torch in d:\application download for education\lib\site-packages (from a2t) (2.8.0)
# Requirement already satisfied: numpy in d:\application download for education\lib\site-packages (from a2t) (2.3.2)
# Requirement already satisfied: scikit-learn in d:\application download for education\lib\site-packages (from a2t) (1.7.1)
# Requirement already satisfied: scipy>=1.8.0 in d:\application download for education\lib\site-packages (from scikit-learn->a2t) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\application download for education\lib\site-packages (from scikit-learn->a2t) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\application download for education\lib\site-packages (from scikit-learn->a2t) (3.6.0)
# Requirement already satisfied: filelock in d:\application download for education\lib\site-packages (from torch->a2t) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\application download for education\lib\site-packages (from torch->a2t) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\application download for education\lib\site-packages (from torch->a2t) (1.14.0)
# Requirement already satisfied: networkx in d:\application download for education\lib\site-packages (from torch->a2t) (3.5)
# Requirement already satisfied: jinja2 in d:\application download for education\lib\site-packages (from torch->a2t) (3.1.6)
# Requirement already satisfied: fsspec in d:\application download for education\lib\site-packages (from torch->a2t) (2025.7.0)
# Requirement already satisfied: setuptools in d:\application download for education\lib\site-packages (from torch->a2t) (80.9.0)
# Requirement already satisfied: colorama in c:\users\vulan\appdata\roaming\python\python313\site-packages (from tqdm->a2t) (0.4.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in d:\application download for education\lib\site-packages (from transformers->a2t) (0.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vulan\appdata\roaming\python\python313\site-packages (from transformers->a2t) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\application download for education\lib\site-packages (from transformers->a2t) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\application download for education\lib\site-packages (from transformers->a2t) (2025.7.34)
# Requirement already satisfied: requests in d:\application download for education\lib\site-packages (from transformers->a2t) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\application download for education\lib\site-packages (from transformers->a2t) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in d:\application download for education\lib\site-packages (from transformers->a2t) (0.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\application download for education\lib\site-packages (from sympy>=1.13.3->torch->a2t) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\application download for education\lib\site-packages (from jinja2->torch->a2t) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\application download for education\lib\site-packages (from requests->transformers->a2t) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\application download for education\lib\site-packages (from requests->transformers->a2t) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\application download for education\lib\site-packages (from requests->transformers->a2t) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\application download for education\lib\site-packages (from requests->transformers->a2t) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json
from types import SimpleNamespace
from a2t.base import EntailmentClassifier
from a2t.tasks import TopicClassificationTask, TopicClassificationFeatures

# %%
# Define your topic labels (customize these based on your needs)
labels = [
    "Technology",
    "Data Analysis", 
    "Natural Language Processing",
    "Education",
    "Personal Development",
    "Literature and Books",
    "Finance and Economics",
    "Programming",
    "Philosophy",
    "General Knowledge"
]

# Create the task
task = TopicClassificationTask(
    name="Prompt Topic Classification",
    labels=labels,
    hypothesis_template="This prompt is about {label}."
)

# Initialize the classifier
nlp = EntailmentClassifier(
    'roberta-large-mnli',
    use_cuda=False,  # Set to True if you have GPU
    half=False
)

# %%
# Load your prompts
df = pd.read_csv('conversation.csv')
prompts = df['title'].tolist()

# %%
from concurrent.futures import ThreadPoolExecutor

import concurrent.futures

MAX_CHARS = 500
truncated_prompts = [text[:MAX_CHARS] for text in prompts]

def classify_batch(batch_texts):
    batch_features = [TopicClassificationFeatures(context=text, label=None) for text in batch_texts]
    return nlp(
        task=task,
        features=batch_features,
        return_labels=True,
        return_confidences=True
    )

# Split into batches and process in parallel
batch_size = 10
batches = [truncated_prompts[i:i+batch_size] for i in range(0, len(truncated_prompts), batch_size)]

all_topics = []
all_confidences = []

with ThreadPoolExecutor(max_workers=4) as executor:
    futures = [executor.submit(classify_batch, batch) for batch in batches]
    for future in concurrent.futures.as_completed(futures):
        topics, confidences = future.result()
        all_topics.extend(topics)
        all_confidences.extend(confidences)

df['predicted_topic'] = all_topics[:len(df)]
df['confidence'] = all_confidences[:len(df)]
# Out:
#  27%|██▋       | 271/988 [02:43<07:11,  1.66it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 5
#       2 truncated_prompts = [text[:MAX_CHARS] for text in prompts]
#       4 all_features = [TopicClassificationFeatures(context=text, label=None) for text in truncated_prompts]
# ----> 5 all_predictions = nlp(
#       6     task=task,
#       7     features=all_features,
#       8     return_labels=True,
#       9     return_confidences=True
#      10 )
#      12 df['predicted_topic'] = all_predictions[0][:len(df)]
#      13 df['confidence'] = all_predictions[1][:len(df)]
#
# File d:\Application Download for Education\Lib\site-packages\a2t\base.py:186, in EntailmentClassifier.__call__(self, task, features, negative_threshold, topk, return_labels, return_confidences, ignore_negative_prediction, return_raw_output, **kwargs)
#     184         data = self.tokenizer(sentence_pairs, return_tensors="pt", padding=True).input_ids
#     185         data = data.to(self.device)
# --> 186         output = self.model(data)[0].detach().cpu().numpy()
#     187         outputs.append(output)
#     189 outputs = np.vstack(outputs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\Application Download for Education\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:1194, in RobertaForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1177 r"""
#    1178 token_type_ids (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1179     Segment token indices to indicate first and second portions of the inputs. Indices are selected in `[0,1]`:
#    (...)   1190     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1191 """
#    1192 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1194 outputs = self.roberta(
#    1195     input_ids,
#    1196     attention_mask=attention_mask,
#    1197     token_type_ids=token_type_ids,
#    1198     position_ids=position_ids,
#    1199     head_mask=head_mask,
#    1200     inputs_embeds=inputs_embeds,
#    1201     output_attentions=output_attentions,
#    1202     output_hidden_states=output_hidden_states,
#    1203     return_dict=return_dict,
#    1204 )
#    1205 sequence_output = outputs[0]
#    1206 logits = self.classifier(sequence_output)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\Application Download for Education\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:868, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     861 # Prepare head mask if needed
#     862 # 1.0 in head_mask indicate we keep the head
#     863 # attention_probs has shape bsz x n_heads x N x N
#     864 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     865 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     866 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 868 encoder_outputs = self.encoder(
#     869     embedding_output,
#     870     attention_mask=extended_attention_mask,
#     871     head_mask=head_mask,
#     872     encoder_hidden_states=encoder_hidden_states,
#     873     encoder_attention_mask=encoder_extended_attention_mask,
#     874     past_key_values=past_key_values,
#     875     use_cache=use_cache,
#     876     output_attentions=output_attentions,
#     877     output_hidden_states=output_hidden_states,
#     878     return_dict=return_dict,
#     879     cache_position=cache_position,
#     880 )
#     881 sequence_output = encoder_outputs[0]
#     882 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\Application Download for Education\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:609, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     605     all_hidden_states = all_hidden_states + (hidden_states,)
#     607 layer_head_mask = head_mask[i] if head_mask is not None else None
# --> 609 layer_outputs = layer_module(
#     610     hidden_states,
#     611     attention_mask,
#     612     layer_head_mask,
#     613     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     614     encoder_attention_mask=encoder_attention_mask,
#     615     past_key_value=past_key_values,
#     616     output_attentions=output_attentions,
#     617     cache_position=cache_position,
#     618 )
#     620 hidden_states = layer_outputs[0]
#     621 if output_attentions:
#
# File d:\Application Download for Education\Lib\site-packages\transformers\modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\Application Download for Education\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:547, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, cache_position)
#     544     attention_output = cross_attention_outputs[0]
#     545     outputs = outputs + cross_attention_outputs[1:]  # add cross attentions if we output attention weights
# --> 547 layer_output = apply_chunking_to_forward(
#     548     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     549 )
#     550 outputs = (layer_output,) + outputs
#     552 return outputs
#
# File d:\Application Download for Education\Lib\site-packages\transformers\pytorch_utils.py:251, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     248     # concatenate output at same dimension
#     249     return torch.cat(output_chunks, dim=chunk_dim)
# --> 251 return forward_fn(*input_tensors)
#
# File d:\Application Download for Education\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:556, in RobertaLayer.feed_forward_chunk(self, attention_output)
#     554 def feed_forward_chunk(self, attention_output):
#     555     intermediate_output = self.intermediate(attention_output)
# --> 556     layer_output = self.output(intermediate_output, attention_output)
#     557     return layer_output
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\Application Download for Education\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:484, in RobertaOutput.forward(self, hidden_states, input_tensor)
#     483 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 484     hidden_states = self.dense(hidden_states)
#     485     hidden_states = self.dropout(hidden_states)
#     486     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# To process all prompts:
all_features = [TopicClassificationFeatures(context=text, label=None) for text in prompts]  # Process first 100
all_predictions = nlp(
    task=task,
    features=all_features,
    return_labels=True,
    return_confidences=True
)

# Add predictions to dataframe
df['predicted_topic'] = all_predictions[0][:len(df)]
df['confidence'] = all_predictions[1][:len(df)]
# Out:
#   1%|          | 1/100 [00:01<02:21,  1.43s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 3
#       1 # To process all prompts:
#       2 all_features = [TopicClassificationFeatures(context=text, label=None) for text in prompts[:100]]  # Process first 100
# ----> 3 all_predictions = nlp(
#       4     task=task,
#       5     features=all_features,
#       6     return_labels=True,
#       7     return_confidences=True
#       8 )
#      10 # Add predictions to dataframe
#      11 df['predicted_topic'] = all_predictions[0][:len(df)]
#
# File d:\Application Download for Education\Lib\site-packages\a2t\base.py:186, in EntailmentClassifier.__call__(self, task, features, negative_threshold, topk, return_labels, return_confidences, ignore_negative_prediction, return_raw_output, **kwargs)
#     184         data = self.tokenizer(sentence_pairs, return_tensors="pt", padding=True).input_ids
#     185         data = data.to(self.device)
# --> 186         output = self.model(data)[0].detach().cpu().numpy()
#     187         outputs.append(output)
#     189 outputs = np.vstack(outputs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\Application Download for Education\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:1194, in RobertaForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1177 r"""
#    1178 token_type_ids (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1179     Segment token indices to indicate first and second portions of the inputs. Indices are selected in `[0,1]`:
#    (...)   1190     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1191 """
#    1192 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1194 outputs = self.roberta(
#    1195     input_ids,
#    1196     attention_mask=attention_mask,
#    1197     token_type_ids=token_type_ids,
#    1198     position_ids=position_ids,
#    1199     head_mask=head_mask,
#    1200     inputs_embeds=inputs_embeds,
#    1201     output_attentions=output_attentions,
#    1202     output_hidden_states=output_hidden_states,
#    1203     return_dict=return_dict,
#    1204 )
#    1205 sequence_output = outputs[0]
#    1206 logits = self.classifier(sequence_output)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\Application Download for Education\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\Application Download for Education\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:799, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     797 if hasattr(self.embeddings, "token_type_ids"):
#     798     buffered_token_type_ids = self.embeddings.token_type_ids[:, :seq_length]
# --> 799     buffered_token_type_ids_expanded = buffered_token_type_ids.expand(batch_size, seq_length)
#     800     token_type_ids = buffered_token_type_ids_expanded
#     801 else:
#
# RuntimeError: The expanded size of the tensor (544) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [10, 544].  Tensor sizes: [1, 514]

# %%
# Process a sample prompt or all prompts
sample_text = "fix this bug?"  # First prompt
features = [TopicClassificationFeatures(context=sample_text, label=None)]

# Get predictions
predictions = nlp(
    task=task,
    features=features,
    return_labels=True,
    return_confidences=True
)

print(f"Prompt: {sample_text}")
print(f"Predictions: {predictions}")
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Prompt: fix this bug?
# Predictions: [('Programming', 0.20142296)]
